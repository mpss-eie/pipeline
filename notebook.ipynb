# %%
import sys
sys.path.insert(1, '../../')

# %%
import pandas as pd

df = pd.read_csv("all_week.csv")
df.head()
# Out:
#                        time   latitude   longitude   depth   mag magType  \
# 0  2024-06-27T06:58:56.234Z  37.085300 -117.455700  1.4000  1.60      ml
# 1  2024-06-27T06:44:54.810Z  38.843334 -122.833664  1.4600  1.19      md
# 2  2024-06-27T06:37:15.170Z  19.379999 -155.248337  0.2600  2.19      ml
# 3  2024-06-27T06:23:40.209Z  31.677000 -104.394000  4.7006  1.60      ml
# 4  2024-06-27T05:40:55.548Z  31.549000 -104.012000  5.5752  1.50      ml
#
#     nst     gap      dmin     rms  ...                   updated  \
# 0  24.0  163.37  0.114000  0.4062  ...  2024-06-27T07:01:24.372Z
# 1   9.0  122.00  0.004948  0.0100  ...  2024-06-27T06:46:34.004Z
# 2  29.0   83.00  0.006159  0.1600  ...  2024-06-27T06:39:54.080Z
# 3  16.0   86.00  0.000000  0.2000  ...  2024-06-27T06:40:06.187Z
# 4  15.0   56.00  0.000000  0.3000  ...  2024-06-27T06:15:46.061Z
#
#                                place        type horizontalError depthError  \
# ...
